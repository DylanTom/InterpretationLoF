# %%
import csv
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('test.csv', index_col=0)
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (20752, 17)

# %%
df = df.iloc[0:10000]

# %%
df = df.dropna(subset = ['ProteinSeq'])

# %%
df.shape #9865/10000
# Out:
# (9865, 17)

# %%
counts = df['CLIN_SIG'].value_counts().tolist()
values = df['CLIN_SIG'].value_counts().keys().tolist()

# %%
plt.pie(counts)
plt.show()

# %%
plt.pie(counts)
plt.legend(labels = values, title="Clinical Significance", loc = "best")
plt.show()

# %%
(20413 - 13063 - 3134 - 1715-45-23)/20413 #12% of the variants have conflicting interpretations
# Out:
# 0.11918875226571303
